# %%
import collections
import datetime
import fluidsynth
import glob
import numpy as np
import pathlib
import pandas as pd
import pretty_midi
import seaborn as sns
import tensorflow as tf

from IPython import display
from matplotlib import pyplot as plt
from typing import Optional

# %%
# Preprocessing: 
# Midi Maestro -> LSTM Input/Output
# Input von Maestro 

# Advantage maestro: no need to filter songs out (example more than 1 instrument)

# %%
# Download Maestro = Midi Files 
data_dir = pathlib.Path('data/maestro-v3.0.0')
if not data_dir.exists():
  tf.keras.utils.get_file(
     'maestro-v3.0.0-midi.zip',
      origin='https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip',
      extract=True,
      cache_dir='.', cache_subdir='data',
  )

# %%
# get sample file from folder
filenames = glob.glob(str(data_dir/'**/*.mid*'))
sample_file = filenames[1]

# %%
# original file loaded from Maestro
print(sample_file)
# Out:
# data\maestro-v3.0.0\2004\MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_06_Track06_wav.midi

# %%
# use pretty_midi for better manipulation
pm = pretty_midi.PrettyMIDI(sample_file)

# %%
print('Number of instruments:', len(pm.instruments))
instrument = pm.instruments[0] # always 0 for us, only piano
# Out:
# Number of instruments: 1

# %%
# Extracting the notes from the sample MIDI file
# step diffrence between notes, duration lenght of note
def midi_to_notes(midi_file: str) -> pd.DataFrame:
    pm = pretty_midi.PrettyMIDI(midi_file)
    instrument = pm.instruments[0]
    notes = collections.defaultdict(list)

    # Sort the notes by start time
    sorted_notes = sorted(instrument.notes, key=lambda note: note.start)
    prev_start = sorted_notes[0].start

    for note in sorted_notes:
        start = note.start
        end = note.end
        notes['pitch'].append(note.pitch)
        notes['start'].append(start)
        notes['end'].append(end)
        notes['step'].append(start - prev_start)
        notes['duration'].append(end - start)
        prev_start = start

    return pd.DataFrame({name: np.array(value) for name, value in notes.items()})

raw_notes = midi_to_notes(sample_file)
raw_notes.head()
# Out:
#    pitch     start       end      step  duration
# 0     43  1.032292  1.111458  0.000000  0.079167
# 1     31  1.040625  1.106250  0.008333  0.065625
# 2     44  1.142708  1.216667  0.102083  0.073958
# 3     32  1.144792  1.217708  0.002083  0.072917
# 4     46  1.208333  1.303125  0.063542  0.094792

# %%
# Converting to note names by considering the respective pitch values

get_note_names = np.vectorize(pretty_midi.note_number_to_name)
sample_note_names = get_note_names(raw_notes['pitch'])
print(sample_note_names[:10])
# could plot as piano roll here
# Out:
# ['G2' 'G1' 'G#2' 'G#1' 'A#2' 'A#1' 'C3' 'C2' 'F3' 'D4']

# %%
# extract notes from midi files and create dataset 
num_files = 5
all_notes = []
for f in filenames[:num_files]:
    notes = midi_to_notes(f)
    all_notes.append(notes)

all_notes = pd.concat(all_notes)

n_notes = len(all_notes)
print('Number of notes parsed:', n_notes)

key_order = ['pitch', 'step', 'duration']
train_notes = np.stack([all_notes[key] for key in key_order], axis=1)

notes_ds = tf.data.Dataset.from_tensor_slices(train_notes)
notes_ds.element_spec
# Out:
# Number of notes parsed: 37241
# TensorSpec(shape=(3,), dtype=tf.float64, name=None)

# %%
def create_sequences(dataset: tf.data.Dataset, seq_length: int,
                     vocab_size = 128) -> tf.data.Dataset:
    """Returns TF Dataset of sequence and label examples."""
    seq_length = seq_length+1

    # Take 1 extra for the labels
    windows = dataset.window(seq_length, shift=1, stride=1,
                              drop_remainder=True)

    # `flat_map` flattens the" dataset of datasets" into a dataset of tensors
    flatten = lambda x: x.batch(seq_length, drop_remainder=True)
    sequences = windows.flat_map(flatten)

    # Normalize note pitch
    def scale_pitch(x):
        x = x/[vocab_size,1.0,1.0]
        return x

    # Split the labels
    def split_labels(sequences):
        inputs = sequences[:-1]
        labels_dense = sequences[-1]
        labels = {key:labels_dense[i] for i,key in enumerate(key_order)}

        return scale_pitch(inputs), labels

    return sequences.map(split_labels, num_parallel_calls=tf.data.AUTOTUNE)

# todo: tune this length
seq_length = 25
vocab_size = 128
seq_ds = create_sequences(notes_ds, seq_length, vocab_size)

# %%
batch_size = 64
buffer_size = n_notes - seq_length  # the number of items in the dataset
train_ds = (seq_ds
            .shuffle(buffer_size)
            .batch(batch_size, drop_remainder=True)
            .cache()
            .prefetch(tf.data.experimental.AUTOTUNE))

# %%
def mse_with_positive_pressure(y_true: tf.Tensor, y_pred: tf.Tensor):
    mse = (y_true - y_pred) ** 2
    positive_pressure = 10 * tf.maximum(-y_pred, 0.0)
    return tf.reduce_mean(mse + positive_pressure)

# %%
input_shape = (seq_length, 3)
learning_rate = 0.005

inputs = tf.keras.Input(input_shape)
x = tf.keras.layers.LSTM(128)(inputs)

outputs = {
  'pitch': tf.keras.layers.Dense(128, name='pitch')(x),
  'step': tf.keras.layers.Dense(1, name='step')(x),
  'duration': tf.keras.layers.Dense(1, name='duration')(x),
}

model = tf.keras.Model(inputs, outputs)

loss = {
      'pitch': tf.keras.losses.SparseCategoricalCrossentropy(
          from_logits=True),
      'step': mse_with_positive_pressure,
      'duration': mse_with_positive_pressure,
}

optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model.compile(loss=loss, optimizer=optimizer)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 25, 3)]              0         []
#
#  lstm_1 (LSTM)               (None, 128)                  67584     ['input_2[0][0]']
#
#  duration (Dense)            (None, 1)                    129       ['lstm_1[0][0]']
#
#  pitch (Dense)               (None, 128)                  16512     ['lstm_1[0][0]']
#
#  step (Dense)                (None, 1)                    129       ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 84354 (329.51 KB)
# Trainable params: 84354 (329.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Creating the necessary callbacks

callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath='./training_checkpoints/ckpt_{epoch}', save_weights_only=True),
             tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, 
                                              verbose=1, restore_best_weights=True),]

# %%
# Compiling and fitting the model

model.compile(loss = loss, 
              loss_weights = {'pitch': 0.05, 'step': 1.0, 'duration':1.0,},
              optimizer = optimizer)

epochs = 50

history = model.fit(train_ds, 
                    epochs=epochs, 
                    callbacks=callbacks,)
# Out:
# Epoch 1/50
# 581/581 [==============================] - 10s 11ms/step - loss: 0.3223 - duration_loss: 0.0844 - pitch_loss: 4.0127 - step_loss: 0.0373
# Epoch 2/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.3121 - duration_loss: 0.0822 - pitch_loss: 3.9066 - step_loss: 0.0345
# Epoch 3/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.3084 - duration_loss: 0.0808 - pitch_loss: 3.8715 - step_loss: 0.0340
# Epoch 4/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.3054 - duration_loss: 0.0799 - pitch_loss: 3.8313 - step_loss: 0.0339
# Epoch 5/50
# 581/581 [==============================] - 7s 12ms/step - loss: 0.3029 - duration_loss: 0.0788 - pitch_loss: 3.8043 - step_loss: 0.0339
# Epoch 6/50
# 581/581 [==============================] - 7s 12ms/step - loss: 0.3009 - duration_loss: 0.0773 - pitch_loss: 3.7981 - step_loss: 0.0337
# Epoch 7/50
# 581/581 [==============================] - 7s 12ms/step - loss: 0.2994 - duration_loss: 0.0766 - pitch_loss: 3.7912 - step_loss: 0.0333
# Epoch 8/50
# 581/581 [==============================] - 7s 12ms/step - loss: 0.2977 - duration_loss: 0.0760 - pitch_loss: 3.7705 - step_loss: 0.0332
# Epoch 9/50
# 581/581 [==============================] - 7s 12ms/step - loss: 0.2952 - duration_loss: 0.0745 - pitch_loss: 3.7677 - step_loss: 0.0324
# Epoch 10/50
# 581/581 [==============================] - 7s 12ms/step - loss: 0.2947 - duration_loss: 0.0748 - pitch_loss: 3.7557 - step_loss: 0.0322
# Epoch 11/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2925 - duration_loss: 0.0732 - pitch_loss: 3.7443 - step_loss: 0.0321
# Epoch 12/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2888 - duration_loss: 0.0714 - pitch_loss: 3.7346 - step_loss: 0.0307
# Epoch 13/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2869 - duration_loss: 0.0707 - pitch_loss: 3.7318 - step_loss: 0.0296
# Epoch 14/50
# 581/581 [==============================] - 7s 12ms/step - loss: 0.2853 - duration_loss: 0.0695 - pitch_loss: 3.7257 - step_loss: 0.0294
# Epoch 15/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2861 - duration_loss: 0.0707 - pitch_loss: 3.7231 - step_loss: 0.0293
# Epoch 16/50
# 581/581 [==============================] - 7s 12ms/step - loss: 0.2813 - duration_loss: 0.0678 - pitch_loss: 3.7130 - step_loss: 0.0279
# Epoch 17/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2763 - duration_loss: 0.0653 - pitch_loss: 3.6944 - step_loss: 0.0263
# Epoch 18/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2784 - duration_loss: 0.0664 - pitch_loss: 3.6884 - step_loss: 0.0276
# Epoch 19/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2730 - duration_loss: 0.0637 - pitch_loss: 3.6684 - step_loss: 0.0259
# Epoch 20/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2677 - duration_loss: 0.0617 - pitch_loss: 3.6501 - step_loss: 0.0234
# Epoch 21/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2655 - duration_loss: 0.0604 - pitch_loss: 3.6485 - step_loss: 0.0227
# Epoch 22/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2629 - duration_loss: 0.0596 - pitch_loss: 3.6390 - step_loss: 0.0213
# Epoch 23/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2600 - duration_loss: 0.0582 - pitch_loss: 3.6297 - step_loss: 0.0204
# Epoch 24/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2586 - duration_loss: 0.0568 - pitch_loss: 3.6218 - step_loss: 0.0207
# Epoch 25/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2557 - duration_loss: 0.0554 - pitch_loss: 3.6150 - step_loss: 0.0195
# Epoch 26/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2670 - duration_loss: 0.0593 - pitch_loss: 3.6272 - step_loss: 0.0264
# Epoch 27/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2555 - duration_loss: 0.0544 - pitch_loss: 3.5975 - step_loss: 0.0212
# Epoch 28/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2533 - duration_loss: 0.0536 - pitch_loss: 3.5859 - step_loss: 0.0205
# Epoch 29/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2553 - duration_loss: 0.0539 - pitch_loss: 3.6131 - step_loss: 0.0207
# Epoch 30/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2512 - duration_loss: 0.0524 - pitch_loss: 3.5945 - step_loss: 0.0191
# Epoch 31/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2527 - duration_loss: 0.0533 - pitch_loss: 3.5973 - step_loss: 0.0196
# Epoch 32/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2533 - duration_loss: 0.0508 - pitch_loss: 3.5819 - step_loss: 0.0234
# Epoch 33/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2460 - duration_loss: 0.0480 - pitch_loss: 3.5625 - step_loss: 0.0199
# Epoch 34/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2466 - duration_loss: 0.0493 - pitch_loss: 3.5864 - step_loss: 0.0181
# Epoch 35/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2442 - duration_loss: 0.0480 - pitch_loss: 3.5748 - step_loss: 0.0174
# Epoch 36/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2405 - duration_loss: 0.0452 - pitch_loss: 3.5707 - step_loss: 0.0168
# Epoch 37/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2409 - duration_loss: 0.0471 - pitch_loss: 3.5520 - step_loss: 0.0162
# Epoch 38/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2371 - duration_loss: 0.0436 - pitch_loss: 3.5518 - step_loss: 0.0159
# Epoch 39/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2413 - duration_loss: 0.0459 - pitch_loss: 3.5614 - step_loss: 0.0173
# Epoch 40/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2343 - duration_loss: 0.0421 - pitch_loss: 3.5371 - step_loss: 0.0153
# Epoch 41/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2301 - duration_loss: 0.0397 - pitch_loss: 3.5239 - step_loss: 0.0142
# Epoch 42/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2273 - duration_loss: 0.0374 - pitch_loss: 3.5155 - step_loss: 0.0141
# Epoch 43/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2286 - duration_loss: 0.0385 - pitch_loss: 3.5273 - step_loss: 0.0137
# Epoch 44/50
# 581/581 [==============================] - 6s 11ms/step - loss: 0.2269 - duration_loss: 0.0375 - pitch_loss: 3.5112 - step_loss: 0.0138
# Epoch 45/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2288 - duration_loss: 0.0398 - pitch_loss: 3.5147 - step_loss: 0.0133
# Epoch 46/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2272 - duration_loss: 0.0375 - pitch_loss: 3.5218 - step_loss: 0.0136
# Epoch 47/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2334 - duration_loss: 0.0436 - pitch_loss: 3.5179 - step_loss: 0.0138
# Epoch 48/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2217 - duration_loss: 0.0352 - pitch_loss: 3.4885 - step_loss: 0.0121
# Epoch 49/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2179 - duration_loss: 0.0331 - pitch_loss: 3.4681 - step_loss: 0.0114
# Epoch 50/50
# 581/581 [==============================] - 7s 11ms/step - loss: 0.2174 - duration_loss: 0.0323 - pitch_loss: 3.4696 - step_loss: 0.0116

# %%
# Gernate Mp3 -> back to midi to play it 

def predict_next_note(notes: np.ndarray, keras_model: tf.keras.Model, 
                      temperature: float = 1.0) -> int:
    """Generates a note IDs using a trained sequence model."""

    assert temperature > 0 # for random note generation so more different notes 

    # Add batch dimension
    inputs = tf.expand_dims(notes, 0)

    predictions = model.predict(inputs)
    pitch_logits = predictions['pitch']
    step = predictions['step']
    duration = predictions['duration']

    pitch_logits /= temperature
    pitch = tf.random.categorical(pitch_logits, num_samples=1)
    pitch = tf.squeeze(pitch, axis=-1)
    duration = tf.squeeze(duration, axis=-1)
    step = tf.squeeze(step, axis=-1)

    # `step` and `duration` values should be non-negative
    step = tf.maximum(0, step)
    duration = tf.maximum(0, duration)

    return int(pitch), float(step), float(duration)

# %%
temperature = 2.0
num_predictions = 120

sample_notes = np.stack([raw_notes[key] for key in key_order], axis=1)

# The initial sequence of notes while the pitch is normalized similar to training sequences
input_notes = (
    sample_notes[:seq_length] / np.array([vocab_size, 1, 1]))

generated_notes = []
prev_start = 0

for _ in range(num_predictions):
    pitch, step, duration = predict_next_note(input_notes, model, temperature)
    start = prev_start + step
    end = start + duration
    input_note = (pitch, step, duration)
    generated_notes.append((*input_note, start, end))
    input_notes = np.delete(input_notes, 0, axis=0)
    input_notes = np.append(input_notes, np.expand_dims(input_note, 0), axis=0)
    prev_start = start

generated_notes = pd.DataFrame(
    generated_notes, columns=(*key_order, 'start', 'end'))

generated_notes.head(10)
# Out:
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
#    pitch      step  duration     start       end
# 0     27  2.261001  0.562444  2.261001  2.823445
# 1     40  0.123716  0.818451  2.384717  3.203169
# 2     95  0.115707  1.073347  2.500425  3.573772
# 3     95  0.116758  1.105555  2.617182  3.722737
# 4     95  0.117715  1.118139  2.734897  3.853036
# 5     97  0.118302  1.124161  2.853200  3.977361
# 6     88  0.118660  1.129194  2.971859  4.101054
# 7     95  0.118870  1.130263  3.090729  4.220992
# 8     95  0.118296  1.122753  3.209025  4.331778
# 9     95  0.120765  1.147499  3.329790  4.477289

# %%
def notes_to_midi(
  notes: pd.DataFrame,
  out_file: str, 
  instrument_name: str,
  velocity: int = 100,  # note loudness
) -> pretty_midi.PrettyMIDI:

  pm = pretty_midi.PrettyMIDI()
  instrument = pretty_midi.Instrument(
      program=pretty_midi.instrument_name_to_program(
          instrument_name))

  prev_start = 0
  for i, note in notes.iterrows():
    start = float(prev_start + note['step'])
    end = float(start + note['duration'])
    note = pretty_midi.Note(
        velocity=velocity,
        pitch=int(note['pitch']),
        start=start,
        end=end,
    )
    instrument.notes.append(note)
    prev_start = start

  pm.instruments.append(instrument)
  pm.write(out_file)
  return pm

# %%
out_file = 'output.midi'
out_pm = notes_to_midi(
    generated_notes, out_file=out_file, 'piano')
# Out:
#   Cell In[31], line 3
#     generated_notes, out_file=out_file, 'piano')
#                                                ^
# SyntaxError: positional argument follows keyword argument
